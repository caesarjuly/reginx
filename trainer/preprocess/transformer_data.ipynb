# %%
import logging
import time

import numpy as np
import matplotlib.pyplot as plt

import tensorflow_datasets as tfds
import tensorflow as tf

import tensorflow_text

# %%
examples, metadata = tfds.load('ted_hrlr_translate/pt_to_en',
                               with_info=True,
                               as_supervised=True)

train_examples, val_examples = examples['train'], examples['validation']
# Out:
# ...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
#
# Dl Completed...:   0%|                                   | 0/1 [00:00<?, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
#
# ...
# Dl Size...:   0%|                                      | 0/124 [00:00<?, ? MiB/s]
#
# Extraction completed...: 0 file [00:00, ? file/s]
# ...
# Dl Size...:   1%|▏                             | 1/124 [00:00<01:31,  1.34 MiB/s]
#
# ...
# Dl Size...:   2%|▍                             | 2/124 [00:00<01:30,  1.34 MiB/s]
#
# ...
# Dl Size...:   2%|▋                             | 3/124 [00:00<01:30,  1.34 MiB/s]
#
# Extraction completed...: 0 file [00:00, ? file/s]
# ...
# Dl Size...:   3%|▉                             | 4/124 [00:00<00:22,  5.32 MiB/s]
#
# ...
# Dl Size...:   4%|█▏                            | 5/124 [00:00<00:22,  5.32 MiB/s]
#
# ...
# Dl Size...:   5%|█▍                            | 6/124 [00:01<00:22,  5.32 MiB/s]
#
# Extraction completed...: 0 file [00:01, ? file/s]
# ...

# %%
for pt_examples, en_examples in train_examples.batch(3).take(1):
    print('> Examples in Portuguese:')
    for pt in pt_examples.numpy():
        print(pt.decode('utf-8'))
    print()

    print('> Examples in English:')
    for en in en_examples.numpy():
        print(en.decode('utf-8'))
# Out:
# > Examples in Portuguese:
# e quando melhoramos a procura , tiramos a única vantagem da impressão , que é a serendipidade .
# mas e se estes fatores fossem ativos ?
# mas eles não tinham a curiosidade de me testar .
#
# > Examples in English:
# and when you improve searchability , you actually take away the one advantage of print , which is serendipity .
# but what if it were active ?
# but they did n't test for curiosity .
# 2023-08-24 14:59:07.847205: W tensorflow/core/kernels/data/cache_dataset_ops.cc:856] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset  will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.

# %%
model_name = 'ted_hrlr_translate_pt_en_converter'
tf.keras.utils.get_file(
    f'{model_name}.zip',
    f'https://storage.googleapis.com/download.tensorflow.org/models/{model_name}.zip',
    cache_dir='.', cache_subdir='', extract=True
)
# Out:
# ...
# 184801/184801 [==============================] - 0s 0us/step
# './ted_hrlr_translate_pt_en_converter.zip'

# %%
tokenizers = tf.saved_model.load(model_name)
[item for item in dir(tokenizers.en) if not item.startswith('_')]
# Out:
# ['detokenize',
#  'get_reserved_tokens',
#  'get_vocab_path',
#  'get_vocab_size',
#  'lookup',
#  'tokenize',
#  'tokenizer',
#  'vocab']

# %%
print('> This is a batch of strings:')
for en in en_examples.numpy():
    print(en.decode('utf-8'))
# Out:
# > This is a batch of strings:
# and when you improve searchability , you actually take away the one advantage of print , which is serendipity .
# but what if it were active ?
# but they did n't test for curiosity .

# %%
encoded = tokenizers.en.tokenize(en_examples)
print('> This is a padded-batch of token IDs:')
for row in encoded.to_list():
    print(row)
# Out:
# > This is a padded-batch of token IDs:
# [2, 72, 117, 79, 1259, 1491, 2362, 13, 79, 150, 184, 311, 71, 103, 2308, 74, 2679, 13, 148, 80, 55, 4840, 1434, 2423, 540, 15, 3]
# [2, 87, 90, 107, 76, 129, 1852, 30, 3]
# [2, 87, 83, 149, 50, 9, 56, 664, 85, 2512, 15, 3]

# %%
round_trip = tokenizers.en.detokenize(encoded)

print('> This is human-readable text:')
for line in round_trip.numpy():
    print(line.decode('utf-8'))
# Out:
# > This is human-readable text:
# and when you improve searchability , you actually take away the one advantage of print , which is serendipity .
# but what if it were active ?
# but they did n ' t test for curiosity .

# %%
print('> This is the text split into tokens:')
tokens = tokenizers.en.lookup(encoded)
tokens
# Out:
# > This is the text split into tokens:
# <tf.RaggedTensor [[b'[START]', b'and', b'when', b'you', b'improve', b'search', b'##ability',
#   b',', b'you', b'actually', b'take', b'away', b'the', b'one', b'advantage',
#   b'of', b'print', b',', b'which', b'is', b's', b'##ere', b'##nd', b'##ip',
#   b'##ity', b'.', b'[END]']                                                 ,
#  [b'[START]', b'but', b'what', b'if', b'it', b'were', b'active', b'?',
#   b'[END]']                                                           ,
#  [b'[START]', b'but', b'they', b'did', b'n', b"'", b't', b'test', b'for',
#   b'curiosity', b'.', b'[END]']                                          ]>

# %%
lengths = []

for pt_examples, en_examples in train_examples.batch(1024):
    pt_tokens = tokenizers.pt.tokenize(pt_examples)
    lengths.append(pt_tokens.row_lengths())

    en_tokens = tokenizers.en.tokenize(en_examples)
    lengths.append(en_tokens.row_lengths())
    print('.', end='', flush=True)
# Out:
# ...................................................

# %%
all_lengths = np.concatenate(lengths)

plt.hist(all_lengths, np.linspace(0, 500, 101))
plt.ylim(plt.ylim())
max_length = max(all_lengths)
plt.plot([max_length, max_length], plt.ylim())
plt.title(f'Maximum tokens per example: {max_length}');

# %%
MAX_TOKENS=128
BATCH_SIZE = 64
def prepare_batch(pt, en):
    pt = tokenizers.pt.tokenize(pt)      # Output is ragged.
    pt = pt[:, :MAX_TOKENS]    # Trim to MAX_TOKENS.
    pt = pt.to_tensor(0, shape=[BATCH_SIZE, MAX_TOKENS])  # Convert to 0-padded dense Tensor

    en = tokenizers.en.tokenize(en)
    en = en[:, :(MAX_TOKENS+1)]
    en_inputs = en[:, :-1].to_tensor(0, shape=[BATCH_SIZE, MAX_TOKENS])  # Drop the [END] tokens
    en_labels = en[:, 1:].to_tensor(0, shape=[BATCH_SIZE, MAX_TOKENS])   # Drop the [START] tokens

    return (pt, en_inputs), en_labels

# %%
BUFFER_SIZE = 20000

def make_batches(ds):
    return (
      ds
      .shuffle(BUFFER_SIZE)
      .batch(BATCH_SIZE)
      .map(prepare_batch, tf.data.AUTOTUNE)
      .unbatch()
      .prefetch(buffer_size=tf.data.AUTOTUNE))

# %%
# Create training and validation set batches.
train_batches = make_batches(train_examples)
val_batches = make_batches(val_examples)
for (pt, en), en_labels in train_batches.take(2):

    print(pt.shape)
    print(en.shape)
    print(en_labels.shape)
# Out:
# (128,)
# (128,)
# (128,)
# (128,)
# (128,)
# (128,)

# %%
print(pt[:10])
print(en[:10])
print(en_labels[:10])
# Out:
# tf.Tensor([   2  108   44  106 4705   16    3    0    0    0], shape=(10,), dtype=int64)
# tf.Tensor([   2   81   80  123 2188   15    0    0    0    0], shape=(10,), dtype=int64)
# tf.Tensor([  81   80  123 2188   15    3    0    0    0    0], shape=(10,), dtype=int64)

# %%
tf.data.experimental.save(train_batches, "/data/translation/train_samples", compression="GZIP")
tf.data.experimental.save(val_batches, "/data/translation/test_samples", compression="GZIP")

# %%
tokenizers.pt.get_vocab_size()
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=7765>

# %%
tokenizers.en.get_vocab_size()
# Out:
# <tf.Tensor: shape=(), dtype=int32, numpy=7010>
